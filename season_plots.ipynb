# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
series_id = '987'

# %%
season_df = pd.read_csv('mfp_league_'+series_id+'_standings.csv')

# %%
season_df.head()
# Out:
#          Unnamed: 0  32486  32487  32488  32489  32490  32491  32492  \
# 0  Nick Fitzpatrick   31.0   23.0   27.0   21.0   28.0    NaN    NaN
# 1    Matthew Talley   25.0   21.0   23.0   21.0   29.0   17.0   31.0
# 2   Will Chernetsky   27.0   16.0   31.0   23.0   25.0   25.0   19.0
# 3   Cary Carmichael    NaN   33.0   19.0   25.0   21.0   21.0   25.0
# 4       Lucy Cachux   23.0   27.0   21.0   27.0   27.0   21.0   19.0
#
#    avg_score  num_games      ...       mean_adj_score  proj_type  proj_score  \
# 0  26.000000        5.0      ...            52.000000          B  138.000000
# 1  23.857143        7.0      ...            47.714286          B  132.714286
# 2  23.714286        7.0      ...            23.714286          B  131.714286
# 3  24.000000        6.0      ...            48.000000          B  131.000000
# 4  23.571429        7.0      ...            47.142857          B  128.142857
#
#    kept_score_att  mean_adj_score_att  proj_score_att  max_score_possible  \
# ...

# %%
season_df.columns
# Out:
# Index([u'Unnamed: 0', u'32486', u'32487', u'32488', u'32489', u'32490',
#        u'32491', u'32492', u'avg_score', u'num_games', u'avg_att', u'proj_att',
#        u'weeks_left_att', u'cur_total', u'cur_score', u'cur_result',
#        u'kept_score', u'mean_adj_score', u'proj_type', u'proj_score',
#        u'kept_score_att', u'mean_adj_score_att', u'proj_score_att',
#        u'max_score_possible', u'remaining_weeks_above_avg', u'score_to_beat',
#        u'required_avg'],
#       dtype='object')

# %%
plt.scatter('cur_score','proj_score_att',data=season_df)

# %%
plt.scatter('cur_result','proj_score',c='cur_score',data=season_df)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
trace = go.Scatter(
  x = season_df.proj_score,
  y = season_df.proj_score_att,
  mode = 'markers',
  text = season_df['Unnamed: 0'],
  marker=dict(
    size=8,
    color = season_df.avg_att,
    colorscale='Portland',
    showscale=True
  )
)
data = [trace]

# %%
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~willnetsky/38.embed" height="525px" width="100%"></iframe>
