# %%
import pandas as pd

# %%
pd.read_excel('mfp_season_bible.xlsx')
# Out:
#     series_id league season_name  Year  ifpa_tournament_id  wpprs  \
# 0         209    MFP   Winter 17  2017             17198.0   8.70
# 1         285    MFP   Spring 17  2017             18813.0   9.87
# 2         350    MFP   Summer 17  2017             18840.0   8.33
# 3         409    MFP     Fall 17  2017             18841.0   8.68
# 4         475    MFP   Winter 18  2018             22440.0   9.29
# 5         582    MFP   Spring 18  2018             22442.0  10.98
# 6         672    MFP   Summer 18  2018             22443.0  12.41
# 7         748    MFP     Fall 18  2018             22444.0  13.04
# 8         861    MFP   Winter 19  2019             28033.0  12.53
# 9         987    MFP   Spring 19  2019             28034.0  13.44
# 10       1080    MFP   Summer 19  2019             28035.0  15.77
# 11       1194    MFP     Fall 19  2019             28036.0  14.24
# 12       1357    MFP   Winter 20  2020             42837.0  18.71
# ...
