# %%
import pandas as pd

# %%
df = pd.read_csv('mfp_all_seasons_full.csv')

# %%
# Out:
#                            Arena  Time  Unnamed: 0  adj_time  group_number  \
# 0      Monster Bash (Remake LE)    607           0     607.0             1
# 1      Monster Bash (Remake LE)    607           1     607.0             1
# 2      Monster Bash (Remake LE)    607           2     607.0             1
# 3      Monster Bash (Remake LE)    607           3     607.0             1
# 4                  Monster Bash    600           4     600.0             2
# ...                          ...   ...         ...       ...           ...
# 24043                Doctor Who    711        1445     948.0             6
# 24044                Doctor Who    711        1446     948.0             6
# 24045                  Baywatch    573        1447     764.0             7
# 24046                  Baywatch    573        1448     764.0             7
# 24047                  Baywatch    573        1449     764.0             7
#
# ...
